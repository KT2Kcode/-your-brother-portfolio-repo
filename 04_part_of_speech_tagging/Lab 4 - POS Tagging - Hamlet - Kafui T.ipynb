# %% [markdown]
# ### Welcome to our Lab #4

# %% [markdown]
# ### Load the following libraries: pandas, numpy, matplotlib, nltk, import sent_tokenize and word_tokenize from nltk, import FreqDist from nltk.probability, import stopwords from nltk.corpus, import WordCloud  from wordcloud, import Image from PIL

# %%
# Standard data manipulation and visualization libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Natural Language Processing tools
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords

# Word cloud visualization
from wordcloud import WordCloud
from PIL import Image

# %% [markdown]
# ### Open the text file hamlet.txt and save it in a variable called: text_file <br> open()

# %%
text_file = open("hamlet.txt")

# %% [markdown]
# ### Read the data and save it in a variable called: text

# %%
def read_text_file(file_path: str) -> str:
    """
    Opens and reads a text file.
    
    Args:
        file_path (str): Path to the text file to be read.
        
    Returns:
        str: The contents of the text file.
        
    Raises:
        FileNotFoundError: If the specified file does not exist.
        IOError: If there's an error reading the file.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            text_file = file.read()
        return text_file
    except FileNotFoundError:
        raise FileNotFoundError(f"The file {file_path} was not found.")
    except IOError as e:
        raise IOError(f"Error reading file {file_path}: {e}")

# %% [markdown]
# ### Display the datatype of the variable "text"

# %%
print (type(text))

# %% [markdown]
# #### Print the text :

# %%
def display_variable_type(variable: any) -> None:
    """
    Display the datatype of the provided variable.
    
    Args:
        variable (any): The variable whose type needs to be displayed.
        
    Returns:
        None: This function prints the type but doesn't return anything.
    """
    print(f"The datatype of the variable is: {type(variable)}")

# %%
# Out:
# 	HAMLET
#
#
# 	DRAMATIS PERSONAE
#
#
# CLAUDIUS	king of Denmark. (KING CLAUDIUS:)
#
# HAMLET	son to the late, and nephew to the present king.
#
# POLONIUS	lord chamberlain. (LORD POLONIUS:)
#
# HORATIO	friend to Hamlet.
#
# LAERTES	son to Polonius.
#
# LUCIANUS	nephew to the king.
#
#
# VOLTIMAND	|
# 	|
# CORNELIUS	|
# 	|
# ROSENCRANTZ	|  courtiers.
# 	|
# GUILDENSTERN	|
# 	|
# OSRIC	|
#
#
# 	A Gentleman, (Gentlemen:)
#
# 	A Priest. (First Priest:)
#
#
# MARCELLUS	|
# 	|  officers.
# BERNARDO	|
#
#
# FRANCISCO	a soldier.
#
# REYNALDO	servant to Polonius.
# 	Players.
# 	(First Player:)
# 	(Player King:)
# 	(Player Queen:)
#
# 	Two Clowns, grave-diggers.
# 	(First Clown:)
# 	(Second Clown:)
#
# FORTINBRAS	prince of Norway. (PRINCE FORTINBRAS:)
#
# 	A Captain.
#
# 	English Ambassadors. (First Ambassador:)
#
# GERTRUDE	queen of Denmark, and mother to Hamlet.
# 	(QUEEN GERTRUDE:)
#
# OPHELIA	daughter to Polonius.
#
# 	Lords, Ladies, Officers, Soldiers, Sailors, Messengers,
# ...

# %% [markdown]
# #### print the length of the text

# %%
# Import nltk for better sentence tokenization
import nltk
# Download the necessary data (only needed once)
nltk.download('punkt')

# Open hamlet.txt and read sentences
with open('hamlet.txt', 'r') as file:
    # Read the entire content
    text = file.read()
    
    # Use nltk to split into sentences
    sentences = nltk.sent_tokenize(text)

print(len(sentences))
# Out:
# 2016
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KTOURNER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### Tokenize the text by sentences <br> sent_tokenize()

# %%
from nltk.tokenize import sent_tokenize

def tokenize_text_by_sentences(text: str) -> list[str]:

    return sent_tokenize(text)

# %% [markdown]
# #### How many sentences are there?

# %%
def count_sentences(text: str) -> int:
    import re
    # Simple sentence detection based on common ending punctuation
    sentences = re.split(r'[.!?]+', text)
    # Filter out empty strings that might result from the split
    sentences = [s for s in sentences if s.strip()]
    return len(sentences)

# %% [markdown]
# #### Print the sentences

# %%
def print_sentences(sentences: list[str]) -> None:
    for sentence in sentences:
        print(sentence)

# %% [markdown]
# #### Tokenize the text with words. Assing them to a variable called: words

# %%
def tokenize_text(text: str) -> list[str]:

    # Simple tokenization by splitting on whitespace
    words = text.split()
    return words

# %% [markdown]
# #### How many words are there?

# %%
def count_words(text: str) -> int:

    if not text:
        return 0
    return len(text.split())

# %% [markdown]
# #### Print the words

# %%
print(count_words)
# Out:
# <function count_words at 0x0000023A2BF0E200>

# %% [markdown]
# #### using a variable "fdist" Find the frequency distribution <br> FreqDist()

# %%
from nltk import FreqDist

fdist = FreqDist(count_words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 from nltk import FreqDist
# ----> 3 fdist = FreqDist(count_words)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\nltk\probability.py:102, in FreqDist.__init__(self, samples)
#      86 def __init__(self, samples=None):
#      87     """
#      88     Construct a new frequency distribution.  If ``samples`` is
#      89     given, then the frequency distribution will be initialized
#    (...)
#     100     :type samples: Sequence
#     101     """
# --> 102     Counter.__init__(self, samples)
#     104     # Cached number of samples in this FreqDist
#     105     self._N = None
#
# File ~\AppData\Local\anaconda3\Lib\collections\__init__.py:597, in Counter.__init__(self, iterable, **kwds)
#     586 '''Create a new, empty Counter object.  And if given, count elements
# ...

# %% [markdown]
# ### Print the 20 most common words

# %%
def print_most_common_words(text: str, n: int = 20) -> None:

    import collections
    import re
    
    # Convert to lowercase and split into words
    words = re.findall(r'\b\w+\b', text.lower())
    
    # Count word frequencies
    word_counts = collections.Counter(words)
    
    # Print the n most common words
    print(f"The {n} most common words:")
    for word, count in word_counts.most_common(n):
        print(f"{word}: {count}")

# %% [markdown]
# #### Plot the graph for fdist

# %%
from nltk import FreqDist
import matplotlib.pyplot as plt

# Assuming words_no_punc is already defined
fdist = FreqDist(count_words)

# Plot the top 20 most common words
fdist.plot(20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Assuming words_no_punc is already defined
# ----> 5 fdist = FreqDist(count_words)
#       7 # Plot the top 20 most common words
#       8 fdist.plot(20)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\nltk\probability.py:102, in FreqDist.__init__(self, samples)
#      86 def __init__(self, samples=None):
#      87     """
#      88     Construct a new frequency distribution.  If ``samples`` is
#      89     given, then the frequency distribution will be initialized
#    (...)
#     100     :type samples: Sequence
#     101     """
# --> 102     Counter.__init__(self, samples)
#     104     # Cached number of samples in this FreqDist
#     105     self._N = None
#
# ...

# %%
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# #### Create an empty list to store words and call it: words_no_punc

# %%
words_no_punc = []

# %% [markdown]
# #### Using a for loop, remove punctuation marks and make them lowercase w.lower()
# Hint:
# for w in words:
#     if w.isalpha():
#         words_no_punc.append(w.lower())

# %%
import string

for word in words:
    if word not in string.punctuation:
        words_no_punc.append(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 import string
# ----> 3 for word in words:
#       4     if word not in string.punctuation:
#       5         words_no_punc.append(word)
#
# NameError: name 'words' is not defined

# %% [markdown]
# #### Print the words without punctution marks

# %%
words_no_punc = []

for w in words:
    if w.isalpha():  # filters out punctuation and numeric tokens
        words_no_punc.append(w.lower())

print(words_no_punc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 words_no_punc = []
# ----> 3 for w in words:
#       4     if w.isalpha():  # filters out punctuation and numeric tokens
#       5         words_no_punc.append(w.lower())
#
# NameError: name 'words' is not defined

# %% [markdown]
# #### print the Length of words_no_punc

# %%
print(len(words_no_punc))
# Out:
# 0

# %% [markdown]
# #### find the Frequency distribution of words_no_punc. Use the variabel fdist

# %%
from nltk import FreqDist

fdist = FreqDist(words_no_punc)

# %% [markdown]
# #### Display the 20 most common words

# %%
print(fdist.most_common(20))
# Out:
# []

# %% [markdown]
# #### Plot the 20 most common words on a grpah:

# %%
from nltk import FreqDist
import matplotlib.pyplot as plt

# Assuming words_no_punc is already defined and populated
fdist = FreqDist(words_no_punc)

# Plot the top 20 most common words
fdist.plot(20, title='Top 20 Most Common Words in Hamlet')
plt.show()

# %%
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# #### Print the List of stopwords from NLTK in English <br> assign them to a variable called: stopwords
# hint:
# stopwords = stopwords.words("english")
# then print them.

# %%
from nltk.corpus import stopwords

# Assign the English stopwords to a variable
stopwords_list = stopwords.words("english")

# Print the list
print(stopwords_list)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %% [markdown]
# #### Create an empty list to store clean words and call it: clean_words

# %%
clean_words = []

# %% [markdown]
# #### Using a for loop, remove stopwords
# hint:
# for w in words_no_punc:
#     if w not in stopwords:
#         clean_words.append(w)

# %%
from nltk.corpus import stopwords

# Load English stopwords
stopwords_list = stopwords.words("english")

# Create an empty list to store filtered words
clean_words = []

# Loop through words_no_punc and filter out stopwords
for w in words_no_punc:
    if w not in stopwords_list:
        clean_words.append(w)

# %% [markdown]
# #### print the clean_words

# %%
print(clean_words)
# Out:
# []

# %% [markdown]
# #### display the lenght of the clean_words

# %%
print(len(clean_words))
# Out:
# 0

# %% [markdown]
# #### find the Frequency distribution and call it: fdist

# %%
from nltk import FreqDist

fdist = FreqDist(clean_words)

# %% [markdown]
# #### find the 20 most common words

# %%
print(fdist.most_common(20))
# Out:
# []

# %% [markdown]
# #### Plot the 20 most common words on grpah:

# %%
from nltk import FreqDist
import matplotlib.pyplot as plt

# Assuming fdist has already been created from clean_words
fdist.plot(20, title='Top 20 Most Common Words in Hamlet (Cleaned)')
plt.show()

# %% [markdown]
# #### Generate the wordcloud and call it: wordcloud
# hint: wordcloud = WordCloud().generate(text)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Convert the list of words into a single string
text = ' '.join(clean_words)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Hamlet (Cleaned)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 8
#       5 text = ' '.join(clean_words)
#       7 # Generate the word cloud
# ----> 8 wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
#      10 # Display the word cloud
#      11 plt.figure(figsize=(10, 5))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:624, in WordCloud.generate_from_text(self, text)
#     607 """Generate wordcloud from text.
#     608
# ...

# %% [markdown]
# #### Plot the wordcloud :

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Convert the list of clean words into a single string
text = ' '.join(clean_words)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Hamlet (Cleaned)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 8
#       5 text = ' '.join(clean_words)
#       7 # Generate the word cloud
# ----> 8 wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
#      10 # Plot the word cloud
#      11 plt.figure(figsize=(10, 5))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:624, in WordCloud.generate_from_text(self, text)
#     607 """Generate wordcloud from text.
#     608
# ...

# %% [markdown]
# ### Using numpy, create an array and assign it to a variable called "char_mask"
# ### In the parameter for the array, use: Image.open("RomeoAndJulietHeart.png")

# %%
from PIL import Image
import numpy as np

# Open the image and convert it to a NumPy array
char_mask = np.array(Image.open("RomeoAndJulietHeart.png"))

# %% [markdown]
# #### Generate a wordcloud using a background_color="white" and mask=char_mask
# hint: wordcloud = WordCloud(background_color="white",mask=char_mask).generate(text)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming 'text' is a string made from 'clean_words'
# and 'char_mask' is a NumPy array from your image

wordcloud = WordCloud(background_color="white", mask=char_mask).generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Hamlet Word Cloud with Heart Mask')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 7
#       2 import matplotlib.pyplot as plt
#       4 # Assuming 'text' is a string made from 'clean_words'
#       5 # and 'char_mask' is a NumPy array from your image
# ----> 7 wordcloud = WordCloud(background_color="white", mask=char_mask).generate(text)
#       9 # Plot the word cloud
#      10 plt.figure(figsize=(10, 8))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# ...

# %% [markdown]
# #### Plot the wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate the word cloud
wordcloud = WordCloud(background_color="white", mask=char_mask).generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Hamlet Word Cloud with Heart Mask')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Generate the word cloud
# ----> 5 wordcloud = WordCloud(background_color="white", mask=char_mask).generate(text)
#       7 # Plot the word cloud
#       8 plt.figure(figsize=(10, 8))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\wordcloud\wordcloud.py:624, in WordCloud.generate_from_text(self, text)
#     607 """Generate wordcloud from text.
#     608
# ...

# %% [markdown]
# #### Assign the top 20 words to a variable called: most_common_words

# %%
most_common_words = fdist.most_common(20)

# %% [markdown]
# #### print the most common words

# %%
print(most_common_words)
# Out:
# []

# %%
# the most common words list's elements are in the form of tuple
# get only the first element of each tuple of the word list

# %%
word_features = [item[0] for item in most_common_words]
print (word_features[:10])
# Out:
# ['hamlet', 'lord', 'king', 'horatio', 'polonius', 'claudius', 'queen', 'shall', 'good', 'come']

# %% [markdown]
# #### Get the tag of those words using nltp.pos_tag()

# %%
import nltk

# Extract just the words from the list of (word, frequency) tuples
top_words_only = [word for word, count in most_common_words]

# Get POS tags
tagged_words = nltk.pos_tag(top_words_only)

# Print the tagged words
print(tagged_words)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[69], line 7
#       4 top_words_only = [word for word, count in most_common_words]
#       6 # Get POS tags
# ----> 7 tagged_words = nltk.pos_tag(top_words_only)
#       9 # Print the tagged words
#      10 print(tagged_words)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
# ...
